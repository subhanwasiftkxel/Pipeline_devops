# %% [markdown]
# ## Automatic Attendance System
#
# ### Multiple check-ins and check-outs are not supported
# ### We track the state of each detected person to avoid multiple entries on the same day
# ### Unknown detections are not logged to the database

# %%
import sqlite3
import cv2
from ultralytics import YOLO
import time
import threading
from datetime import datetime, timedelta

# %%
model = YOLO(r"C:\Users\Hamza\Desktop\Deep Learning\Assignment 3\best.pt")

# %%
conn = sqlite3.connect('attendance25.db')
conn.execute('''CREATE TABLE IF NOT EXISTS attendance_records
             (id INTEGER PRIMARY KEY,
              name TEXT NOT NULL,
              date TEXT NOT NULL,
              check_in_time INTEGER,
              check_out_time INTEGER,
              working_time INTEGER)''')
conn.commit()

# %%
conn

# %%
day_counter = 0
custom_time_counter = 0

# %%
# Global flags for thread control
day_counter_running = True
time_counter_running = True

# %%
# Base date for the simulation set to today's date
base_date = datetime.now().date()

# %%
# Function to get simulated date based on day_counter
def get_simulated_date(day_counter):
    return base_date + timedelta(days=day_counter)

# %%
def increment_day_counter():
    global day_counter, day_counter_running
    while day_counter_running:
        time.sleep(8)
        day_counter += 1

# %%
def increment_custom_time_counter():
    global custom_time_counter, time_counter_running
    while time_counter_running:
        time.sleep(1)
        custom_time_counter += 1

# %%
# Start the day and custom time counter threads
day_counter_thread = threading.Thread(target=increment_day_counter, daemon=True)
day_counter_thread.start()
custom_time_counter_thread = threading.Thread(target=increment_custom_time_counter, daemon=True)
custom_time_counter_thread.start()

# %%
# Function to get current time offset within the day
def get_time_offset():
    return custom_time_counter % 8

# %%
# Function to update attendance
def update_attendance(name):
    global day_counter
    current_time_offset = get_time_offset()
    simulated_date = get_simulated_date(day_counter)
    date_str = simulated_date.strftime("%Y-%m-%d")

    cursor = conn.execute("SELECT id, check_in_time, check_out_time FROM attendance_records WHERE name=? AND date=?", (name, date_str))
    record = cursor.fetchone()

    if record:
        if record[2] is None:
            working_time = min(30, current_time_offset - record[1])
            conn.execute("UPDATE attendance_records SET check_out_time=?, working_time=? WHERE id=?", (current_time_offset, working_time, record[0]))
            print(f"Checked out {name} with working time {working_time} seconds.")
    else:
        conn.execute("INSERT INTO attendance_records (name, date, check_in_time) VALUES (?, ?, ?)", (name, date_str, current_time_offset))
        print(f"Checked in {name} at time offset {current_time_offset}.")
    conn.commit()

# %%
# Function to stop threads
def stop_threads():
    global day_counter_running, time_counter_running
    day_counter_running = False
    time_counter_running = False

# %%
# Start video capture
cap = cv2.VideoCapture(0)

# Tracking the state of each detected person 
person_states = {}

# Process video frames
while cap.isOpened():
    success, frame = cap.read()
    if success:
        results = model(frame)

        detected_names = set()
        for result in results:
            boxes = result.boxes.cpu().numpy()
            for box in boxes:
                person_name = result.names[int(box.cls[0])]
                detected_names.add(person_name)

                if person_states.get(person_name, 'not_detected') == 'not_detected':
                    update_attendance(person_name)
                    person_states[person_name] = 'detected'

        for name in person_states.keys():
            if name not in detected_names:
                person_states[name] = 'not_detected'

        cv2.imshow("YOLOv8 Inference", frame)

        if cv2.waitKey(1) & 0xFF == ord('q'):
            break
    else:
        break

# Release resources and stop threads
cap.release()
cv2.destroyAllWindows()
stop_threads()
day_counter_thread.join()
custom_time_counter_thread.join()
conn.close()
# Out:
# 0: 480x640 1 Me, 1 My friend, 164.1ms
# Speed: 5.7ms preprocess, 164.1ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 640)
# Checked in My friend at time offset 0.
# Checked in Me at time offset 0.
#
# 0: 480x640 1 My friend, 173.6ms
# Speed: 1.9ms preprocess, 173.6ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 My friend, 149.1ms
# Speed: 2.0ms preprocess, 149.1ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 My friend, 143.7ms
# Speed: 3.0ms preprocess, 143.7ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 My friend, 141.0ms
# Speed: 2.0ms preprocess, 141.0ms inference, 1.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 My friend, 143.4ms
# Speed: 2.2ms preprocess, 143.4ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 My friend, 135.7ms
# Speed: 2.4ms preprocess, 135.7ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 My friend, 135.8ms
# Speed: 2.0ms preprocess, 135.8ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 My friend, 110.9ms
# Speed: 1.0ms preprocess, 110.9ms inference, 1.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 My friend, 115.4ms
# Speed: 1.0ms preprocess, 115.4ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 My friend, 122.7ms
# Speed: 2.0ms preprocess, 122.7ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 137.6ms
# Speed: 2.0ms preprocess, 137.6ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 My friend, 131.9ms
# Speed: 2.0ms preprocess, 131.9ms inference, 1.1ms postprocess per image at shape (1, 3, 480, 640)
# Checked out My friend with working time 2 seconds.
#
# 0: 480x640 (no detections), 165.3ms
# Speed: 2.3ms preprocess, 165.3ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 148.4ms
# Speed: 0.8ms preprocess, 148.4ms inference, 1.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 116.4ms
# Speed: 3.0ms preprocess, 116.4ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 133.3ms
# Speed: 2.0ms preprocess, 133.3ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 128.9ms
# Speed: 2.0ms preprocess, 128.9ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 120.4ms
# Speed: 1.9ms preprocess, 120.4ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 My friend, 101.9ms
# Speed: 2.1ms preprocess, 101.9ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 My friend, 117.2ms
# Speed: 1.1ms preprocess, 117.2ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 My friend, 120.2ms
# Speed: 1.0ms preprocess, 120.2ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 My friend, 106.6ms
# Speed: 3.0ms preprocess, 106.6ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 My friend, 101.9ms
# Speed: 1.0ms preprocess, 101.9ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 My friend, 142.8ms
# Speed: 2.5ms preprocess, 142.8ms inference, 1.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 My friend, 146.8ms
# Speed: 3.0ms preprocess, 146.8ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 My friend, 113.2ms
# Speed: 1.0ms preprocess, 113.2ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 My friend, 131.4ms
# Speed: 1.0ms preprocess, 131.4ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 My friend, 145.5ms
# Speed: 1.2ms preprocess, 145.5ms inference, 1.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 My friend, 145.3ms
# Speed: 2.0ms preprocess, 145.3ms inference, 1.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 143.3ms
# Speed: 1.0ms preprocess, 143.3ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 118.4ms
# Speed: 3.1ms preprocess, 118.4ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 113.3ms
# Speed: 2.0ms preprocess, 113.3ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 148.5ms
# Speed: 4.0ms preprocess, 148.5ms inference, 1.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 147.2ms
# Speed: 3.0ms preprocess, 147.2ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 138.8ms
# Speed: 1.9ms preprocess, 138.8ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 141.1ms
# Speed: 1.9ms preprocess, 141.1ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 133.6ms
# Speed: 2.0ms preprocess, 133.6ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 My friends, 131.7ms
# Speed: 2.0ms preprocess, 131.7ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 My friend, 145.3ms
# Speed: 1.1ms preprocess, 145.3ms inference, 1.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 My friend, 144.6ms
# Speed: 2.0ms preprocess, 144.6ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 My friend, 145.7ms
# Speed: 1.0ms preprocess, 145.7ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 My friend, 147.1ms
# Speed: 2.0ms preprocess, 147.1ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 My friend, 139.7ms
# Speed: 1.9ms preprocess, 139.7ms inference, 2.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 My friend, 141.2ms
# Speed: 2.0ms preprocess, 141.2ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 My friend, 132.4ms
# Speed: 3.7ms preprocess, 132.4ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 My friend, 132.1ms
# Speed: 1.0ms preprocess, 132.1ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 My friend, 139.9ms
# Speed: 1.0ms preprocess, 139.9ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 My friend, 149.7ms
# Speed: 2.0ms preprocess, 149.7ms inference, 1.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 143.2ms
# Speed: 0.9ms preprocess, 143.2ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 148.3ms
# Speed: 1.9ms preprocess, 148.3ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 150.2ms
# Speed: 2.0ms preprocess, 150.2ms inference, 1.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 148.6ms
# Speed: 2.0ms preprocess, 148.6ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 155.7ms
# Speed: 1.9ms preprocess, 155.7ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 155.1ms
# Speed: 2.1ms preprocess, 155.1ms inference, 1.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 145.3ms
# Speed: 3.9ms preprocess, 145.3ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 149.8ms
# Speed: 2.0ms preprocess, 149.8ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 149.0ms
# Speed: 2.0ms preprocess, 149.0ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 My friend, 151.5ms
# Speed: 2.0ms preprocess, 151.5ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
# Checked in My friend at time offset 1.
#
# 0: 480x640 1 My friend, 135.3ms
# Speed: 1.9ms preprocess, 135.3ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 My friend, 146.7ms
# Speed: 2.0ms preprocess, 146.7ms inference, 1.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 My friend, 152.0ms
# Speed: 2.0ms preprocess, 152.0ms inference, 1.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 My friend, 151.0ms
# Speed: 1.9ms preprocess, 151.0ms inference, 1.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 My friend, 144.9ms
# Speed: 2.0ms preprocess, 144.9ms inference, 1.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 My friend, 140.8ms
# Speed: 3.0ms preprocess, 140.8ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 My friend, 127.3ms
# Speed: 1.9ms preprocess, 127.3ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 My friend, 134.5ms
# Speed: 2.2ms preprocess, 134.5ms inference, 1.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 My friend, 151.5ms
# Speed: 2.0ms preprocess, 151.5ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 My friend, 139.5ms
# Speed: 1.9ms preprocess, 139.5ms inference, 1.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 139.0ms
# Speed: 1.0ms preprocess, 139.0ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 144.3ms
# Speed: 1.9ms preprocess, 144.3ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 131.5ms
# Speed: 2.0ms preprocess, 131.5ms inference, 1.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 139.8ms
# Speed: 1.0ms preprocess, 139.8ms inference, 1.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 132.3ms
# Speed: 2.0ms preprocess, 132.3ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 137.2ms
# Speed: 2.5ms preprocess, 137.2ms inference, 1.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 132.9ms
# Speed: 0.9ms preprocess, 132.9ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 140.9ms
# Speed: 1.5ms preprocess, 140.9ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 134.5ms
# Speed: 2.0ms preprocess, 134.5ms inference, 1.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 My friend, 139.8ms
# Speed: 1.0ms preprocess, 139.8ms inference, 2.1ms postprocess per image at shape (1, 3, 480, 640)
# Checked out My friend with working time 3 seconds.
#
# 0: 480x640 1 My friend, 139.3ms
# Speed: 2.0ms preprocess, 139.3ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 My friend, 135.6ms
# Speed: 1.0ms preprocess, 135.6ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 My friend, 125.8ms
# Speed: 0.9ms preprocess, 125.8ms inference, 1.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 My friend, 134.7ms
# Speed: 1.0ms preprocess, 134.7ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 My friend, 143.5ms
# Speed: 2.0ms preprocess, 143.5ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 My friend, 131.7ms
# Speed: 3.0ms preprocess, 131.7ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 My friend, 142.7ms
# Speed: 2.0ms preprocess, 142.7ms inference, 1.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 My friend, 134.2ms
# Speed: 1.9ms preprocess, 134.2ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 My friend, 139.9ms
# Speed: 2.0ms preprocess, 139.9ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 My friend, 141.3ms
# Speed: 2.0ms preprocess, 141.3ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 My friend, 147.8ms
# Speed: 2.0ms preprocess, 147.8ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 My friend, 139.3ms
# Speed: 2.1ms preprocess, 139.3ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 141.9ms
# Speed: 2.0ms preprocess, 141.9ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 140.3ms
# Speed: 0.9ms preprocess, 140.3ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 143.6ms
# Speed: 0.9ms preprocess, 143.6ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 142.3ms
# Speed: 0.9ms preprocess, 142.3ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 141.7ms
# Speed: 1.9ms preprocess, 141.7ms inference, 1.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 139.0ms
# Speed: 0.9ms preprocess, 139.0ms inference, 1.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 147.1ms
# Speed: 2.0ms preprocess, 147.1ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 141.1ms
# Speed: 1.9ms preprocess, 141.1ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 136.6ms
# Speed: 1.0ms preprocess, 136.6ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 My friend, 142.2ms
# Speed: 1.0ms preprocess, 142.2ms inference, 1.1ms postprocess per image at shape (1, 3, 480, 640)
# Checked in My friend at time offset 0.
#
# 0: 480x640 1 My friend, 142.4ms
# Speed: 1.9ms preprocess, 142.4ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 My friend, 142.1ms
# Speed: 2.0ms preprocess, 142.1ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 My friend, 136.4ms
# Speed: 1.9ms preprocess, 136.4ms inference, 1.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 My friend, 143.2ms
# Speed: 1.0ms preprocess, 143.2ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 My friend, 137.3ms
# Speed: 2.0ms preprocess, 137.3ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 My friend, 144.0ms
# Speed: 2.0ms preprocess, 144.0ms inference, 1.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 My friend, 130.9ms
# Speed: 1.5ms preprocess, 130.9ms inference, 1.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 My friend, 148.8ms
# Speed: 2.0ms preprocess, 148.8ms inference, 1.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 My friend, 142.7ms
# Speed: 2.0ms preprocess, 142.7ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 My friend, 139.3ms
# Speed: 1.0ms preprocess, 139.3ms inference, 1.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 My friend, 142.0ms
# Speed: 2.0ms preprocess, 142.0ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 My friend, 152.1ms
# Speed: 2.0ms preprocess, 152.1ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 143.3ms
# Speed: 1.5ms preprocess, 143.3ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 136.2ms
# Speed: 2.5ms preprocess, 136.2ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 142.1ms
# Speed: 0.9ms preprocess, 142.1ms inference, 1.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 144.3ms
# Speed: 1.9ms preprocess, 144.3ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 137.8ms
# Speed: 2.1ms preprocess, 137.8ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 147.4ms
# Speed: 1.1ms preprocess, 147.4ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 148.3ms
# Speed: 1.8ms preprocess, 148.3ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 128.1ms
# Speed: 2.0ms preprocess, 128.1ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 157.1ms
# Speed: 1.9ms preprocess, 157.1ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 My friend, 138.8ms
# Speed: 2.0ms preprocess, 138.8ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
# Checked out My friend with working time 3 seconds.
#
# 0: 480x640 1 My friend, 146.4ms
# Speed: 2.9ms preprocess, 146.4ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 My friend, 153.4ms
# Speed: 3.5ms preprocess, 153.4ms inference, 1.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 My friend, 136.7ms
# Speed: 0.9ms preprocess, 136.7ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 My friend, 153.0ms
# Speed: 2.1ms preprocess, 153.0ms inference, 1.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 My friend, 139.0ms
# Speed: 2.1ms preprocess, 139.0ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 My friend, 112.6ms
# Speed: 0.9ms preprocess, 112.6ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 My friend, 136.6ms
# Speed: 2.1ms preprocess, 136.6ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 My friend, 138.4ms
# Speed: 2.0ms preprocess, 138.4ms inference, 1.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 My friend, 155.1ms
# Speed: 1.0ms preprocess, 155.1ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 My friend, 145.3ms
# Speed: 1.0ms preprocess, 145.3ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 My friend, 136.5ms
# Speed: 1.0ms preprocess, 136.5ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 128.9ms
# Speed: 1.0ms preprocess, 128.9ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 130.1ms
# Speed: 2.0ms preprocess, 130.1ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 134.0ms
# Speed: 0.9ms preprocess, 134.0ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 155.9ms
# Speed: 1.0ms preprocess, 155.9ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 142.4ms
# Speed: 1.0ms preprocess, 142.4ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 138.5ms
# Speed: 0.9ms preprocess, 138.5ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 137.0ms
# Speed: 2.0ms preprocess, 137.0ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 140.8ms
# Speed: 2.0ms preprocess, 140.8ms inference, 1.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 137.4ms
# Speed: 1.9ms preprocess, 137.4ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 My friend, 132.8ms
# Speed: 2.0ms preprocess, 132.8ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 My friend, 142.3ms
# Speed: 3.0ms preprocess, 142.3ms inference, 1.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 My friend, 128.9ms
# Speed: 2.0ms preprocess, 128.9ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 My friend, 142.7ms
# Speed: 2.0ms preprocess, 142.7ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 My friend, 136.7ms
# Speed: 0.9ms preprocess, 136.7ms inference, 1.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 My friend, 136.2ms
# Speed: 1.1ms preprocess, 136.2ms inference, 1.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 My friend, 152.7ms
# Speed: 1.0ms preprocess, 152.7ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 My friend, 146.8ms
# Speed: 2.0ms preprocess, 146.8ms inference, 2.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 My friend, 140.7ms
# Speed: 1.9ms preprocess, 140.7ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 My friend, 149.6ms
# Speed: 2.0ms preprocess, 149.6ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 My friend, 139.0ms
# Speed: 2.0ms preprocess, 139.0ms inference, 1.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 My friend, 140.0ms
# Speed: 0.9ms preprocess, 140.0ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 151.1ms
# Speed: 1.0ms preprocess, 151.1ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 143.9ms
# Speed: 0.9ms preprocess, 143.9ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 138.6ms
# Speed: 1.0ms preprocess, 138.6ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 146.8ms
# Speed: 1.0ms preprocess, 146.8ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 124.8ms
# Speed: 1.0ms preprocess, 124.8ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 130.6ms
# Speed: 1.0ms preprocess, 130.6ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 141.8ms
# Speed: 1.0ms preprocess, 141.8ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 143.7ms
# Speed: 1.0ms preprocess, 143.7ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 My friend, 142.1ms
# Speed: 2.4ms preprocess, 142.1ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
# Checked in My friend at time offset 2.
#
# 0: 480x640 1 My friend, 137.7ms
# Speed: 1.0ms preprocess, 137.7ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 My friend, 141.1ms
# Speed: 0.9ms preprocess, 141.1ms inference, 1.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 My friend, 136.5ms
# Speed: 1.0ms preprocess, 136.5ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 My friend, 145.6ms
# Speed: 1.0ms preprocess, 145.6ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 My friend, 146.5ms
# Speed: 2.1ms preprocess, 146.5ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 My friend, 119.9ms
# Speed: 0.9ms preprocess, 119.9ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 My friend, 139.8ms
# Speed: 2.0ms preprocess, 139.8ms inference, 1.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 My friend, 140.2ms
# Speed: 2.0ms preprocess, 140.2ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 My friend, 142.7ms
# Speed: 1.6ms preprocess, 142.7ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 My friend, 137.2ms
# Speed: 2.0ms preprocess, 137.2ms inference, 1.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 My friend, 148.3ms
# Speed: 1.0ms preprocess, 148.3ms inference, 1.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 151.3ms
# Speed: 1.1ms preprocess, 151.3ms inference, 1.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 148.9ms
# Speed: 2.9ms preprocess, 148.9ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 136.5ms
# Speed: 2.0ms preprocess, 136.5ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 131.2ms
# Speed: 1.9ms preprocess, 131.2ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 124.5ms
# Speed: 1.9ms preprocess, 124.5ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 139.8ms
# Speed: 2.0ms preprocess, 139.8ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 142.1ms
# Speed: 2.0ms preprocess, 142.1ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 142.8ms
# Speed: 1.9ms preprocess, 142.8ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 135.9ms
# Speed: 2.1ms preprocess, 135.9ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 142.0ms
# Speed: 2.0ms preprocess, 142.0ms inference, 1.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 My friend, 142.4ms
# Speed: 1.0ms preprocess, 142.4ms inference, 1.1ms postprocess per image at shape (1, 3, 480, 640)
# Checked out My friend with working time 3 seconds.
#
# 0: 480x640 1 My friend, 133.3ms
# Speed: 2.0ms preprocess, 133.3ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 My friend, 142.6ms
# Speed: 1.9ms preprocess, 142.6ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 My friend, 137.2ms
# Speed: 1.9ms preprocess, 137.2ms inference, 1.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 My friend, 135.9ms
# Speed: 1.0ms preprocess, 135.9ms inference, 1.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 My friend, 143.9ms
# Speed: 2.0ms preprocess, 143.9ms inference, 1.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 My friend, 127.3ms
# Speed: 2.9ms preprocess, 127.3ms inference, 0.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 My friend, 106.8ms
# Speed: 1.9ms preprocess, 106.8ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 My friend, 115.2ms
# Speed: 2.4ms preprocess, 115.2ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 My friend, 125.2ms
# Speed: 2.0ms preprocess, 125.2ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 137.5ms
# Speed: 2.0ms preprocess, 137.5ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 145.9ms
# Speed: 1.0ms preprocess, 145.9ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 116.7ms
# Speed: 1.0ms preprocess, 116.7ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 131.3ms
# Speed: 2.0ms preprocess, 131.3ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 139.9ms
# Speed: 2.0ms preprocess, 139.9ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 136.1ms
# Speed: 1.0ms preprocess, 136.1ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 My friends, 174.1ms
# Speed: 2.0ms preprocess, 174.1ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 640)
# Checked in My friend at time offset 0.
#
# 0: 480x640 1 My friend, 139.1ms
# Speed: 1.8ms preprocess, 139.1ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 My friend, 133.3ms
# Speed: 1.3ms preprocess, 133.3ms inference, 1.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 My friend, 133.4ms
# Speed: 1.9ms preprocess, 133.4ms inference, 1.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 My friend, 137.4ms
# Speed: 1.1ms preprocess, 137.4ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 My friend, 141.1ms
# Speed: 2.1ms preprocess, 141.1ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 My friend, 133.0ms
# Speed: 2.0ms preprocess, 133.0ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 My friend, 141.3ms
# Speed: 1.0ms preprocess, 141.3ms inference, 1.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 My friend, 142.7ms
# Speed: 2.1ms preprocess, 142.7ms inference, 1.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 155.9ms
# Speed: 1.5ms preprocess, 155.9ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 154.4ms
# Speed: 3.0ms preprocess, 154.4ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 147.3ms
# Speed: 2.9ms preprocess, 147.3ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 147.3ms
# Speed: 1.9ms preprocess, 147.3ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 143.3ms
# Speed: 0.9ms preprocess, 143.3ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 143.2ms
# Speed: 2.0ms preprocess, 143.2ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 156.7ms
# Speed: 2.4ms preprocess, 156.7ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 145.2ms
# Speed: 2.0ms preprocess, 145.2ms inference, 1.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 My friend, 142.9ms
# Speed: 2.1ms preprocess, 142.9ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
# Checked out My friend with working time 2 seconds.
#
# 0: 480x640 1 My friend, 135.8ms
# Speed: 2.0ms preprocess, 135.8ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 My friend, 149.5ms
# Speed: 1.0ms preprocess, 149.5ms inference, 1.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 My friend, 159.5ms
# Speed: 2.2ms preprocess, 159.5ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 My friend, 138.0ms
# Speed: 2.0ms preprocess, 138.0ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 My friend, 148.8ms
# Speed: 1.0ms preprocess, 148.8ms inference, 1.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 My friend, 140.3ms
# Speed: 2.0ms preprocess, 140.3ms inference, 1.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 My friend, 139.3ms
# Speed: 1.8ms preprocess, 139.3ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 My friend, 151.3ms
# Speed: 2.0ms preprocess, 151.3ms inference, 1.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 My friend, 150.0ms
# Speed: 2.0ms preprocess, 150.0ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 My friend, 144.0ms
# Speed: 1.0ms preprocess, 144.0ms inference, 1.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 140.7ms
# Speed: 1.9ms preprocess, 140.7ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 136.1ms
# Speed: 1.9ms preprocess, 136.1ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 154.7ms
# Speed: 2.0ms preprocess, 154.7ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 151.6ms
# Speed: 2.0ms preprocess, 151.6ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 152.4ms
# Speed: 1.9ms preprocess, 152.4ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 154.6ms
# Speed: 2.0ms preprocess, 154.6ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 153.6ms
# Speed: 2.0ms preprocess, 153.6ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 153.5ms
# Speed: 1.8ms preprocess, 153.5ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 144.5ms
# Speed: 1.0ms preprocess, 144.5ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 140.6ms
# Speed: 1.9ms preprocess, 140.6ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 My friend, 130.3ms
# Speed: 1.8ms preprocess, 130.3ms inference, 1.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 My friend, 142.4ms
# Speed: 2.0ms preprocess, 142.4ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 My friend, 131.6ms
# Speed: 1.0ms preprocess, 131.6ms inference, 1.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 My friend, 144.8ms
# Speed: 1.0ms preprocess, 144.8ms inference, 1.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 My friend, 148.8ms
# Speed: 1.0ms preprocess, 148.8ms inference, 1.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 My friend, 133.3ms
# Speed: 1.9ms preprocess, 133.3ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 My friend, 140.5ms
# Speed: 2.0ms preprocess, 140.5ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 My friend, 135.1ms
# Speed: 2.0ms preprocess, 135.1ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 My friend, 137.3ms
# Speed: 2.0ms preprocess, 137.3ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 My friend, 131.9ms
# Speed: 2.0ms preprocess, 131.9ms inference, 1.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 My friend, 141.3ms
# Speed: 1.9ms preprocess, 141.3ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 My friend, 141.2ms
# Speed: 1.0ms preprocess, 141.2ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 My friend, 141.2ms
# Speed: 1.1ms preprocess, 141.2ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 My friend, 136.3ms
# Speed: 2.0ms preprocess, 136.3ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 My friend, 135.1ms
# Speed: 1.9ms preprocess, 135.1ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 140.7ms
# Speed: 1.9ms preprocess, 140.7ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 140.2ms
# Speed: 2.0ms preprocess, 140.2ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 134.7ms
# Speed: 1.0ms preprocess, 134.7ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 141.8ms
# Speed: 1.9ms preprocess, 141.8ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 137.3ms
# Speed: 2.0ms preprocess, 137.3ms inference, 1.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 132.0ms
# Speed: 0.9ms preprocess, 132.0ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 133.3ms
# Speed: 1.0ms preprocess, 133.3ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 My friend, 151.9ms
# Speed: 1.0ms preprocess, 151.9ms inference, 1.1ms postprocess per image at shape (1, 3, 480, 640)
# Checked in My friend at time offset 1.
#
# 0: 480x640 1 My friend, 142.0ms
# Speed: 2.6ms preprocess, 142.0ms inference, 1.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 My friend, 132.6ms
# Speed: 2.0ms preprocess, 132.6ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 My friend, 138.5ms
# Speed: 1.0ms preprocess, 138.5ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 My friend, 136.9ms
# Speed: 2.9ms preprocess, 136.9ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 My friend, 137.9ms
# Speed: 2.2ms preprocess, 137.9ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)

# %%
# View database records
# Connect to the database
conn = sqlite3.connect('attendance25.db')

# Create a cursor object
cursor = conn.cursor()

# Fetch all records
cursor.execute("SELECT * FROM attendance_records")
records = cursor.fetchall()

# Print records
for record in records:
    print(record)

# Close the connection
conn.close()
# Out:
# (1, 'My friend', '2024-01-16', 0, 2, 2)
# (2, 'Me', '2024-01-16', 0, None, None)
# (3, 'My friend', '2024-01-17', 1, 4, 3)
# (4, 'My friend', '2024-01-18', 0, 3, 3)
# (5, 'My friend', '2024-01-19', 2, 5, 3)
# (6, 'My friend', '2024-01-20', 0, 2, 2)
# (7, 'My friend', '2024-01-21', 1, None, None)
